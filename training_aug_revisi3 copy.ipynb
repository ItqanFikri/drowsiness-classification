# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from collections import Counter
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from scipy import stats
from tensorflow.keras.regularizers import l2
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Dense, Flatten, Dropout, Bidirectional, LeakyReLU, BatchNormalization, AveragePooling1D
from tensorflow.keras import optimizers
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from ind_rnn import IndRNNCell,IndRNN
import os
import pandas as pd
from collections import Counter
from sklearn.preprocessing import StandardScaler
from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from tensorflow.keras.optimizers import Adam

# %%
# Constants
WINDOW_LEN = 5400
N_FEATURE = 2

# Define the paths in a dictionary (for train, val, and test)
data_paths = {
    'train': [
        'F:/Tugas Akhir/Split_revisi_3-1/train/shuffled_1_train.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/train/shuffled_2_train.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/train/shuffled_3_train.npy',
    ],
    'val': [
        'F:/Tugas Akhir/Split_revisi_3-1/val/shuffled_1_val.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/val/shuffled_2_val.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/val/shuffled_3_val.npy',
    ],
    'test': [
        'F:/Tugas Akhir/Split_revisi_3-1/test/shuffled_1_test.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/test/shuffled_2_test.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/test/shuffled_3_test.npy',
    ]
}

# Function to load, process, and one-hot encode data
def load_and_process_data(data_paths):
    processed_data = {}
    
    for split in ['train', 'val', 'test']:
        x_data = []
        y_data = []
        
        # Load and concatenate data
        for path in data_paths[split]:
            data = np.load(path, allow_pickle=True)  # allow_pickle=True to load object arrays if needed
            # Mengakses fitur 'ear_x', 'mar_x', dan 'label'
            ear_x = data[:, :, 0]  # Semua window, semua elemen dalam window, kolom 0 (ear_x)
            mar_x = data[:, :, 1]  # Semua window, semua elemen dalam window, kolom 1 (mar_x)
            label = data[:, 0, 2]  # Semua window, label diambil dari elemen pertama
            
            # Combine 'ear_x' and 'mar_x' as features (combine along axis 1)
            features = np.stack((ear_x, mar_x), axis=-1)  # Shape: (samples, WINDOW_LEN, N_FEATURE)
            
            x_data.append(features)
            y_data.append(label)
        
        # Concatenate along the first axis (samples)
        x_data = np.vstack(x_data)
        y_data = np.concatenate(y_data)
        
        # One-hot encode the labels (0 -> [1, 0], 1 -> [0, 1])
        y_data = pd.get_dummies(y_data).values  # Shape: (num_samples, 2)
        
        # Store the processed data
        processed_data[split] = (x_data, y_data)
        
    return processed_data

# Load and process the data
processed_data = load_and_process_data(data_paths)

# Access the processed data
x_train, y_train = processed_data['train']
x_val, y_val = processed_data['val']
x_test, y_test = processed_data['test']

# Reshape the data to (samples, WINDOW_LEN, N_FEATURE)
x_train = x_train.reshape(-1, WINDOW_LEN, N_FEATURE)
x_val = x_val.reshape(-1, WINDOW_LEN, N_FEATURE)
x_test = x_test.reshape(-1, WINDOW_LEN, N_FEATURE)

# Check the shapes
print(f"Train data shape: {x_train.shape}, Train labels shape: {y_train.shape}")
print(f"Validation data shape: {x_val.shape}, Validation labels shape: {y_val.shape}")
print(f"Test data shape: {x_test.shape}, Test labels shape: {y_test.shape}")
# Out:
# Train data shape: (213, 5400, 2), Train labels shape: (213, 3)
# Validation data shape: (72, 5400, 2), Validation labels shape: (72, 3)
# Test data shape: (93, 5400, 2), Test labels shape: (93, 3)

# %%
import numpy as np

# Ganti 'path_to_file.npy' dengan path file .npy Anda
file_path = 'F:/Tugas Akhir/Split_revisi_3-1/train/shuffled_1_train.npy'

# Membaca file npy
data = np.load(file_path)

# Melihat data
print("Data dari file:")
print(data)

# Menampilkan informasi data
print("\nTipe data:", type(data))
print("Shape data:", data.shape)
print("Data type elemen:", data.dtype)
# Out:
# Data dari file:
# [[[0.72323275 0.25       1.        ]
#   [0.79664585 0.25       1.        ]
#   [0.79219614 0.25       1.        ]
#   ...
#   [0.69778602 0.25       1.        ]
#   [0.67613709 0.25       1.        ]
#   [0.69690189 0.25       1.        ]]
#
#  [[0.73655329 0.25       1.        ]
#   [0.73655329 0.25       1.        ]
#   [0.73655329 0.25       1.        ]
#   ...
#   [0.67959638 0.29052244 1.        ]
#   [0.67856085 0.27290928 1.        ]
#   [0.67856085 0.27290928 1.        ]]
#
#  [[0.78000367 0.25       1.        ]
#   [0.8143596  0.25       1.        ]
#   [0.7627898  0.25       1.        ]
#   ...
#   [0.76066949 0.25       1.        ]
#   [0.76624173 0.25       1.        ]
#   [0.79201174 0.25       1.        ]]
#
#  ...
#
#  [[0.70659101 0.25       1.        ]
#   [0.77895792 0.27220861 1.        ]
#   [0.70325153 0.3001392  1.        ]
#   ...
#   [0.7288498  0.31696236 1.        ]
#   [0.73870356 0.31456016 1.        ]
#   [0.7245837  0.32576281 1.        ]]
#
#  [[0.92811641 0.25       1.        ]
#   [0.92173357 0.25       1.        ]
#   [0.8769791  0.25       1.        ]
#   ...
#   [0.88852326 0.25       1.        ]
#   [0.86442423 0.25       1.        ]
#   [0.87742634 0.25       1.        ]]
#
#  [[0.70650736 0.25       1.        ]
#   [0.81539088 0.25       1.        ]
#   [0.87907943 0.25       1.        ]
#   ...
#   [0.83934088 0.25       1.        ]
#   [0.83389506 0.25       1.        ]
#   [0.78728831 0.25       1.        ]]]
#
# Tipe data: <class 'numpy.ndarray'>
# Shape data: (71, 5400, 3)
# Data type elemen: float64

# %%
optimizers = Adam(learning_rate=0.0001)

def create_model():
    model = Sequential()
    
    # model.add(Bidirectional(IndRNN(32, return_sequences=True, kernel_regularizer=l2(1e-4)), 
    #                         input_shape=(WINDOW_LEN, N_FEATURE)))
    
    model.add(IndRNN(32, return_sequences=True, kernel_regularizer=l2(1e-6), 
                            input_shape=(WINDOW_LEN, N_FEATURE)))

    
    # Fully connected layers
    model.add(Flatten())  # Flatten the output from the CNN layers
    model.add(Dense(16))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Dropout(0.5))
    model.add(Dense(8))
    model.add(LeakyReLU(alpha=0.1))
    model.add(Dropout(0.5))
    model.add(Dense(3, activation='softmax'))

    # Compile the model
    model.compile(optimizer=optimizers, metrics=['accuracy'], loss='categorical_crossentropy')
    
    return model

# Initialize the model
model = create_model()

# Optional: Print the model summary
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  ind_rnn_2 (IndRNN)          (None, 5400, 32)          96
#
#  flatten_2 (Flatten)         (None, 172800)            0
#
#  dense_6 (Dense)             (None, 16)                2764816
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 16)                0
#
#  dropout_4 (Dropout)         (None, 16)                0
#
#  dense_7 (Dense)             (None, 8)                 136
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 8)                 0
#
#  dropout_5 (Dropout)         (None, 8)                 0
#
#  dense_8 (Dense)             (None, 3)                 27
#
# =================================================================
# Total params: 2,765,075
# Trainable params: 2,765,075
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define callbacks
model_checkpoint = ModelCheckpoint('./model_slide_window/IndRNNAug5400_Slide_revisi.h5', monitor='val_accuracy', 
                                   save_best_only=True, verbose=1)
early_stopping = EarlyStopping(monitor='val_loss', patience=800, verbose=1)

# Train the model
history = model.fit(x_train, y_train, validation_data=(x_val, y_val), batch_size=8, epochs=800, callbacks=[model_checkpoint, early_stopping])

np.save('./model_slide_window/training_history_5400_Slide_revisi.npy', history.history)

# Evaluate the model using the test data
test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'Test accuracy: {test_acc}')
print(f'Test loss: {test_loss}')
# Out:
# Epoch 1/800
# 27/27 [==============================] - ETA: 0s - loss: 1.5695 - accuracy: 0.3568
# Epoch 1: val_accuracy improved from -inf to 0.33333, saving model to ./model_slide_window\IndRNNAug5400_Slide_revisi.h5
# 27/27 [==============================] - 19s 655ms/step - loss: 1.5695 - accuracy: 0.3568 - val_loss: 1.1204 - val_accuracy: 0.3333
# Epoch 2/800
# 27/27 [==============================] - ETA: 0s - loss: 1.2875 - accuracy: 0.3099
# Epoch 2: val_accuracy did not improve from 0.33333
# 27/27 [==============================] - 17s 616ms/step - loss: 1.2875 - accuracy: 0.3099 - val_loss: 1.1120 - val_accuracy: 0.3333
# Epoch 3/800
# 27/27 [==============================] - ETA: 0s - loss: 1.1953 - accuracy: 0.3052
# Epoch 3: val_accuracy did not improve from 0.33333
# 27/27 [==============================] - 17s 620ms/step - loss: 1.1953 - accuracy: 0.3052 - val_loss: 1.1023 - val_accuracy: 0.3333
# Epoch 4/800
# 27/27 [==============================] - ETA: 0s - loss: 1.1863 - accuracy: 0.3286
# Epoch 4: val_accuracy improved from 0.33333 to 0.34722, saving model to ./model_slide_window\IndRNNAug5400_Slide_revisi.h5
# 27/27 [==============================] - 17s 623ms/step - loss: 1.1863 - accuracy: 0.3286 - val_loss: 1.1505 - val_accuracy: 0.3472
# Epoch 5/800
# 27/27 [==============================] - ETA: 0s - loss: 1.2600 - accuracy: 0.3568
# Epoch 5: val_accuracy improved from 0.34722 to 0.37500, saving model to ./model_slide_window\IndRNNAug5400_Slide_revisi.h5
# 27/27 [==============================] - 18s 659ms/step - loss: 1.2600 - accuracy: 0.3568 - val_loss: 1.1019 - val_accuracy: 0.3750
# Epoch 6/800
# 27/27 [==============================] - ETA: 0s - loss: 1.3004 - accuracy: 0.2864
# Epoch 6: val_accuracy did not improve from 0.37500
# 27/27 [==============================] - 17s 627ms/step - loss: 1.3004 - accuracy: 0.2864 - val_loss: 1.1035 - val_accuracy: 0.3333
# Epoch 7/800
# 27/27 [==============================] - ETA: 0s - loss: 1.2021 - accuracy: 0.3474
# Epoch 7: val_accuracy did not improve from 0.37500
# 27/27 [==============================] - 22s 844ms/step - loss: 1.2021 - accuracy: 0.3474 - val_loss: 1.1013 - val_accuracy: 0.3333
# Epoch 8/800
# 27/27 [==============================] - ETA: 0s - loss: 1.2418 - accuracy: 0.3286
# Epoch 8: val_accuracy did not improve from 0.37500
# 27/27 [==============================] - 16s 600ms/step - loss: 1.2418 - accuracy: 0.3286 - val_loss: 1.0997 - val_accuracy: 0.3333
# Epoch 9/800
# 27/27 [==============================] - ETA: 0s - loss: 1.
# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
import random
from tensorflow.keras.regularizers import l2

# Set random seed for reproducibility
np.random.seed(3)
random.seed(3)
tf.random.set_seed(3)

# Load the saved model with custom object and compile it
model = load_model('./model_slide_window/IndRNNAug5400_Slide_revisi.h5', custom_objects={'IndRNN': IndRNN}, compile=False)

# Recompile the model with the same optimizer and loss
model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# Evaluate the model on the test data
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=1)

# Print the test accuracy
print("Test Accuracy: {:.2f}%".format(test_accuracy * 100))
# Out:
# 3/3 [==============================] - 1s 222ms/step - loss: 4.6726 - accuracy: 0.4731
# Test Accuracy: 47.31%

# %%
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2
import random
import numpy as np
import tensorflow as tf
from ind_rnn import IndRNN
import os
assert os.path.exists('F:\Tugas Akhir\Itqan\model_slide_window/IndRNNAug5400_Slide_revisi.h5'), "File tidak ditemukan!"
import h5py

file_path = r'F:\Tugas Akhir\Itqan\model_slide_window/IndRNNAug5400_Slide_revisi.h5'

try:
    with h5py.File(file_path, 'r') as f:
        print("File .h5 berhasil dibuka dan valid.")
except Exception as e:
    print(f"File tidak valid atau korup: {e}")


def find_best_seed(model_path, x_test, y_test, custom_objects, seed_range):
    """
    Mencari seed terbaik berdasarkan akurasi model.

    Parameters:
    - model_path (str): Path ke model yang disimpan.
    - x_test (np.ndarray): Data uji (fitur).
    - y_test (np.ndarray): Data uji (label).
    - custom_objects (dict): Custom objects untuk load_model.
    - seed_range (list): Daftar seed yang ingin diuji.

    Returns:
    - best_seed (int): Seed terbaik berdasarkan akurasi tertinggi.
    - best_accuracy (float): Akurasi tertinggi.
    - results (dict): Dictionary dengan semua seed dan akurasi.
    """
    results = {}
    best_seed = None
    best_accuracy = 0.0

    for seed in seed_range:
        # Set random seed
        np.random.seed(seed)
        random.seed(seed)
        tf.random.set_seed(seed)
        
        # Load the saved model
        model = load_model(model_path, custom_objects=custom_objects, compile=False)
        
        # Recompile the model
        model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
        
        # Evaluate the model
        test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
        
        # Store the accuracy for the seed
        results[seed] = test_accuracy
        
        # Check if this seed gives the best accuracy
        if test_accuracy > best_accuracy:
            best_seed = seed
            best_accuracy = test_accuracy
        
        print(f"Seed {seed} - Test Accuracy: {test_accuracy:.4f}")
    
    return best_seed, best_accuracy, results

# Path ke file model
model_path = r'F:\Tugas Akhir\Itqan\model_slide_window/IndRNNAug5400_Slide_revisi.h5'

# Rentang seed yang ingin diuji
seed_range = range(0, 1000)  # Mencoba seed dari 0 hingga 50

# Muat model dengan custom objects
model = load_model(model_path, custom_objects={'IndRNN': IndRNN}, compile=False)

custom_objects={'IndRNN': IndRNN}

# Cari seed terbaik
best_seed, best_accuracy, results = find_best_seed(model_path, x_test, y_test, custom_objects, seed_range)

print("\nSeed terbaik:", best_seed)
print("Akurasi tertinggi: {:.2f}%".format(best_accuracy * 100))
# Out:
# File .h5 berhasil dibuka dan valid.
# Seed 0 - Test Accuracy: 0.4731
# Seed 1 - Test Accuracy: 0.4624
# Seed 2 - Test Accuracy: 0.4194
# Seed 3 - Test Accuracy: 0.4731
# Seed 4 - Test Accuracy: 0.4301
# Seed 5 - Test Accuracy: 0.3226
# Seed 6 - Test Accuracy: 0.3548
# Seed 7 - Test Accuracy: 0.3978
# Seed 8 - Test Accuracy: 0.4301
# Seed 9 - Test Accuracy: 0.4409
# Seed 10 - Test Accuracy: 0.3333
# Seed 11 - Test Accuracy: 0.3548
# Seed 12 - Test Accuracy: 0.4516
# Seed 13 - Test Accuracy: 0.4624
# Seed 14 - Test Accuracy: 0.4516
# Seed 15 - Test Accuracy: 0.4194
# Seed 16 - Test Accuracy: 0.4301
# Seed 17 - Test Accuracy: 0.4194
# Seed 18 - Test Accuracy: 0.4731
# Seed 19 - Test Accuracy: 0.4301
# Seed 20 - Test Accuracy: 0.3978
# Seed 21 - Test Accuracy: 0.4624
# Seed 22 - Test Accuracy: 0.4086
# Seed 23 - Test Accuracy: 0.4516
# Seed 24 - Test Accuracy: 0.4946
# Seed 25 - Test Accuracy: 0.3978
# Seed 26 - Test Accuracy: 0.4624
# Seed 27 - Test Accuracy: 0.4516
# Seed 28 - Test Accuracy: 0.3871
# Seed 29 - Test Accuracy: 0.3656
# Seed 30 - Test Accuracy: 0.4409
# Seed 31 - Test Accuracy: 0.4516
# Seed 32 - Test Accuracy: 0.5376
# Seed 33 - Test Accuracy: 0.3333
# Seed 34 - Test Accuracy: 0.3978
# Seed 35 - Test Accuracy: 0.4946
# Seed 36 - Test Accuracy: 0.4086
# Seed 37 - Test Accuracy: 0.3656
# Seed 38 - Test Accuracy: 0.4409
# Seed 39 - Test Accuracy: 0.4946
# Seed 40 - Test Accuracy: 0.4409
# Seed 41 - Test Accuracy: 0.4516
# Seed 42 - Test Accuracy: 0.4516
# Seed 43 - Test Accuracy: 0.4194
# Seed 44 - Test Accuracy: 0.5376
# Seed 45 - Test Accuracy: 0.3656
# Seed 46 - Test Accuracy: 0.4409
# Seed 47 - Test Accuracy: 0.3548
# Seed 48 - Test Accuracy: 0.4086
# Seed 49 - Test Accuracy: 0.3978
# Seed 50 - Test Accuracy: 0.3871
# Seed 51 - Test Accuracy: 0.4516
# Seed 52 - Test Accuracy: 0.5054
# Seed 53 - Test Accuracy: 0.4624
# Seed 54 - Test Accuracy: 0.4731
# Seed 55 - Test Accuracy: 0.4086
# Seed 56 - Test Accuracy: 0.4301
# Seed 57 - Test Accuracy: 0.3978
# Seed 58 - Test Accuracy: 0.4624
# Seed 59 - Test Accuracy: 0.3871
# Seed 60 - Test Accuracy: 0.4301
# Seed 61 - Test Accuracy: 0.4301
# Seed 62 - Test Accuracy: 0.3871
# Seed 63 - Test Accuracy: 0.2473
# Seed 64 - Test Accuracy: 0.4301
# Seed 65 - Test Accuracy: 0.4194
# Seed 66 - Test Accuracy: 0.4516
# Seed 67 - Test Accuracy: 0.3978
# Seed 68 - Test Accuracy: 0.3656
# Seed 69 - Test Accuracy: 0.4731
# Seed 70 - Test Accuracy: 0.4839
# Seed 71 - Test Accuracy: 0.4301
# Seed 72 - Test Accuracy: 0.3548
# Seed 73 - Test Accuracy: 0.4409
# Seed 74 - Test Accuracy: 0.3333
# Seed 75 - Test Accuracy: 0.4194
# Seed 76 - Test Accuracy: 0.4086
# Seed 77 - Test Accuracy: 0.5054
# Seed 78 - Test Accuracy: 0.5054
# Seed 79 - Test Accuracy: 0.3978
# Seed 80 - Test Accuracy: 0.4516
# Seed 81 - Test Accuracy: 0.4194
# Seed 82 - Test Accuracy: 0.4946
# Seed 83 - Test Accuracy: 0.3548
# Seed 84 - Test Accuracy: 0.4301
# Seed 85 - Test Accuracy: 0.4086
# Seed 86 - Test Accuracy: 0.4194
# Seed 87 - Test Accuracy: 0.4839
# Seed 88 - Test Accuracy: 0.4409
# Seed 89 - Test Accuracy: 0.3656
# Seed 90 - Test Accuracy: 0.4731
# Seed 91 - Test Accuracy: 0.4731
# Seed 92 - Test Accuracy: 0.4516
# Seed 93 - Test Accuracy: 0.4731
# Seed 94 - Test Accuracy: 0.4624
# Seed 95 - Test Accuracy: 0.4301
# Seed 96 - Test Accuracy: 0.4409
# Seed 97 - Test Accuracy: 0.3548
# Seed 98 - Test Accuracy: 0.3978
# Seed 99 - Test Accuracy: 0.4624
# Seed 100 - Test Accuracy: 0.4731
# Seed 101 - Test Accuracy: 0.5161
# Seed 102 - Test Accuracy: 0.4086
# Seed 103 - Test Accuracy: 0.4624
# Seed 104 - Test Accuracy: 0.4624
# Seed 105 - Test Accuracy: 0.3333
# Seed 106 - Test Accuracy: 0.4301
# Seed 107 - Test Accuracy: 0.4516
# Seed 108 - Test Accuracy: 0.4946
# Seed 109 - Test Accuracy: 0.4624
# Seed 110 - Test Accuracy: 0.3978
# Seed 111 - Test Accuracy: 0.3118
# Seed 112 - Test Accuracy: 0.4839
# Seed 113 - Test Accuracy: 0.4516
# Seed 114 - Test Accuracy: 0.4409
# Seed 115 - Test Accuracy: 0.3333
# Seed 116 - Test Accuracy: 0.4624
# Seed 117 - Test Accuracy: 0.4731
# Seed 118 - Test Accuracy: 0.4086
# Seed 119 - Test Accuracy: 0.4624
# Seed 120 - Test Accuracy: 0.4516
# Seed 121 - Test Accuracy: 0.4409
# Seed 122 - Test Accuracy: 0.4839
# Seed 123 - Test Accuracy: 0.3548
# Seed 124 - Test Accuracy: 0.4731
# Seed 125 - Test Accuracy: 0.4839
# Seed 126 - Test Accuracy: 0.5269
# Seed 127 - Test Accuracy: 0.3763
# Seed 128 - Test Accuracy: 0.4731
# Seed 129 - Test Accuracy: 0.4409
# Seed 130 - Test Accuracy: 0.4624
# Seed 131 - Test Accuracy: 0.4839
# Seed 132 - Test Accuracy: 0.4839
# Seed 133 - Test Accuracy: 0.3656
# Seed 134 - Test Accuracy: 0.4194
# Seed 135 - Test Accuracy: 0.5054
# Seed 136 - Test Accuracy: 0.4624
# Seed 137 - Test Accuracy: 0.4946
# Seed 138 - Test Accuracy: 0.4409
# Seed 139 - Test Accuracy: 0.4086
# Seed 140 - Test Accuracy: 0.4624
# Seed 141 - Test Accuracy: 0.4839
# Seed 142 - Test Accuracy: 0.3871
# Seed 143 - Test Accuracy: 0.4409
# Seed 144 - Test Accuracy: 0.4839
# Seed 145 - Test Accuracy: 0.4731
# Seed 146 - Test Accuracy: 0.4086
# Seed 147 - Test Accuracy: 0.5054
# Seed 148 - Test Accuracy: 0.4516
# Seed 149 - Test Accuracy: 0.4194
# Seed 150 - Test Accuracy: 0.4301
# Seed 151 - Test Accuracy: 0.4516
# Seed 152 - Test Accuracy: 0.5054
# Seed 153 - Test Accuracy: 0.4409
# Seed 154 - Test Accuracy: 0.4516
# Seed 155 - Test Accuracy: 0.3978
# Seed 156 - Test Accuracy: 0.4086
# Seed 157 - Test Accuracy: 0.4731
# Seed 158 - Test Accuracy: 0.4624
# Seed 159 - Test Accuracy: 0.4194
# Seed 160 - Test Accuracy: 0.4301
# Seed 161 - Test Accuracy: 0.4516
# Seed 162 - Test Accuracy: 0.3441
# Seed 163 - Test Accuracy: 0.3763
# Seed 164 - Test Accuracy: 0.4194
# Seed 165 - Test Accuracy: 0.4194
# Seed 166 - Test Accuracy: 0.3978
# Seed 167 - Test Accuracy: 0.4839
# Seed 168 - Test Accuracy: 0.4624
# Seed 169 - Test Accuracy: 0.3871
# Seed 170 - Test Accuracy: 0.4086
# Seed 171 - Test Accuracy: 0.4301
# Seed 172 - Test Accuracy: 0.5376
# Seed 173 - Test Accuracy: 0.4086
# Seed 174 - Test Accuracy: 0.5054
# Seed 175 - Test Accuracy: 0.4624
# Seed 176 - Test Accuracy: 0.4194
# Seed 177 - Test Accuracy: 0.3763
# Seed 178 - Test Accuracy: 0.4839
# Seed 179 - Test Accuracy: 0.3548
# Seed 180 - Test Accuracy: 0.4624
# Seed 181 - Test Accuracy: 0.4086
# Seed 182 - Test Accuracy: 0.4086
# Seed 183 - Test Accuracy: 0.4409
# Seed 184 - Test Accuracy: 0.4086
# Seed 185 - Test Accuracy: 0.4409
# Seed 186 - Test Accuracy: 0.4731
# Seed 187 - Test Accuracy: 0.4301
# Seed 188 - Test Accuracy: 0.4086
# Seed 189 - Test Accuracy: 0.5054
# Seed 190 - Test Accuracy: 0.4409
# Seed 191 - Test Accuracy: 0.4731
# Seed 192 - Test Accuracy: 0.4839
# Seed 193 - Test Accuracy: 0.4301
# Seed 194 - Test Accuracy: 0.3333
# Seed 195 - Test Accuracy: 0.3011
# Seed 196 - Test Accuracy: 0.4409
# Seed 197 - Test Accuracy: 0.4086
# Seed 198 - Test Accuracy: 0.4731
# Seed 199 - Test Accuracy: 0.4194
# Seed 200 - Test Accuracy: 0.4301
# Seed 201 - Test Accuracy: 0.3763
# Seed 202 - Test Accuracy: 0.4409
# Seed 203 - Test Accuracy: 0.5161
# Seed 204 - Test Accuracy: 0.3333
# Seed 205 - Test Accuracy: 0.4731
# Seed 206 - Test Accuracy: 0.3763
# Seed 207 - Test Accuracy: 0.4409
# Seed 208 - Test Accuracy: 0.4516
# Seed 209 - Test Accuracy: 0.4409
# Seed 210 - Test Accuracy: 0.4946
# Seed 211 - Test Accuracy: 0.3441
# Seed 212 - Test Accuracy: 0.3656
# Seed 213 - Test Accuracy: 0.4194
# Seed 214 - Test Accuracy: 0.3978
# Seed 215 - Test Accuracy: 0.3226
# Seed 216 - Test Accuracy: 0.4409
# Seed 217 - Test Accuracy: 0.3978
# Seed 218 - Test Accuracy: 0.3978
# Seed 219 - Test Accuracy: 0.3978
# Seed 220 - Test Accuracy: 0.4409
# Seed 221 - Test Accuracy: 0.3656
# Seed 222 - Test Accuracy: 0.4409
# Seed 223 - Test Accuracy: 0.4839
# Seed 224 - Test Accuracy: 0.4086
# Seed 225 - Test Accuracy: 0.4946
# Seed 226 - Test Accuracy: 0.4516
# Seed 227 - Test Accuracy: 0.3333
# Seed 228 - Test Accuracy: 0.3011
# Seed 229 - Test Accuracy: 0.4731
# Seed 230 - Test Accuracy: 0.4409
# Seed 231 - Test Accuracy: 0.3441
# Seed 232 - Test Accuracy: 0.4194
# Seed 233 - Test Accuracy: 0.3548
# Seed 234 - Test Accuracy: 0.3978
# Seed 235 - Test Accuracy: 0.4731
# Seed 236 - Test Accuracy: 0.4731
# Seed 237 - Test Accuracy: 0.4516
# Seed 238 - Test Accuracy: 0.4301
# Seed 239 - Test Accuracy: 0.4946
# Seed 240 - Test Accuracy: 0.3871
# Seed 241 - Test Accuracy: 0.3333
# Seed 242 - Test Accuracy: 0.4409
# Seed 243 - Test Accuracy: 0.4086
# Seed 244 - Test Accuracy: 0.3656
# Seed 245 - Test Accuracy: 0.3333
# Seed 246 - Test Accuracy: 0.3763
# Seed 247 - Test Accuracy: 0.3226
# Seed 248 - Test Accuracy: 0.4946
# Seed 249 - Test Accuracy: 0.4516
# Seed 250 - Test Accuracy: 0.4301
# Seed 251 - Test Accuracy: 0.4624
# Seed 252 - Test Accuracy: 0.4731
# Seed 253 - Test Accuracy: 0.4301
# Seed 254 - Test Accuracy: 0.4624
# Seed 255 - Test Accuracy: 0.3978
# Seed 256 - Test Accuracy: 0.5054
# Seed 257 - Test Accuracy: 0.4624
# Seed 258 - Test Accuracy: 0.4409
# Seed 259 - Test Accuracy: 0.4624
# Seed 260 - Test Accuracy: 0.4946
# Seed 261 - Test Accuracy: 0.5054
# Seed 262 - Test Accuracy: 0.4516
# Seed 263 - Test Accuracy: 0.3978
# Seed 264 - Test Accuracy: 0.4301
# Seed 265 - Test Accuracy: 0.4409
# Seed 266 - Test Accuracy: 0.5161
# Seed 267 - Test Accuracy: 0.4301
# Seed 268 - Test Accuracy: 0.3871
# Seed 269 - Test Accuracy: 0.3226
# Seed 270 - Test Accuracy: 0.3441
# Seed 271 - Test Accuracy: 0.4946
# Seed 272 - Test Accuracy: 0.5054
# Seed 273 - Test Accuracy: 0.3441
# Seed 274 - Test Accuracy: 0.4409
# Seed 275 - Test Accuracy: 0.4839
# Seed 276 - Test Accuracy: 0.4516
# Seed 277 - Test Accuracy: 0.4839
# Seed 278 - Test Accuracy: 0.4086
# Seed 279 - Test Accuracy: 0.4301
# Seed 280 - Test Accuracy: 0.4624
# Seed 281 - Test Accuracy: 0.5054
# Seed 282 - Test Accuracy: 0.5161
# Seed 283 - Test Accuracy: 0.3871
# Seed 284 - Test Accuracy: 0.3978
# Seed 285 - Test Accuracy: 0.3656
# Seed 286 - Test Accuracy: 0.4731
# Seed 287 - Test Accuracy: 0.3871
# Seed 288 - Test Accuracy: 0.4194
# Seed 289 - Test Accuracy: 0.4839
# Seed 290 - Test Accuracy: 0.4839
# Seed 291 - Test Accuracy: 0.3978
# Seed 292 - Test Accuracy: 0.4409
# Seed 293 - Test Accuracy: 0.3871
# Seed 294 - Test Accuracy: 0.4624
# Seed 295 - Test Accuracy: 0.2903
# Seed 296 - Test Accuracy: 0.4409
# Seed 297 - Test Accuracy: 0.3656
# Seed 298 - Test Accuracy: 0.3333
# Seed 299 - Test Accuracy: 0.3763
# Seed 300 - Test Accuracy: 0.4731
# Seed 301 - Test Accuracy: 0.4516
# Seed 302 - Test Accuracy: 0.3763
# Seed 303 - Test Accuracy: 0.5054
# Seed 304 - Test Accuracy: 0.4301
# Seed 305 - Test Accuracy: 0.4946
# Seed 306 - Test Accuracy: 0.4731
# Seed 307 - Test Accuracy: 0.4731
# Seed 308 - Test Accuracy: 0.3226
# Seed 309 - Test Accuracy: 0.4194
# Seed 310 - Test Accuracy: 0.5161
# Seed 311 - Test Accuracy: 0.4624
# Seed 312 - Test Accuracy: 0.4624
# Seed 313 - Test Accuracy: 0.3333
# Seed 314 - Test Accuracy: 0.3548
# Seed 315 - Test Accuracy: 0.4086
# Seed 316 - Test Accuracy: 0.4946
# Seed 317 - Test Accuracy: 0.3333
# Seed 318 - Test Accuracy: 0.4624
# Seed 319 - Test Accuracy: 0.4086
# Seed 320 - Test Accuracy: 0.4624
# Seed 321 - Test Accuracy: 0.4624
# Seed 322 - Test Accuracy: 0.3548
# Seed 323 - Test Accuracy: 0.4946
# Seed 324 - Test Accuracy: 0.5054
# Seed 325 - Test Accuracy: 0.3978
# Seed 326 - Test Accuracy: 0.4946
# Seed 327 - Test Accuracy: 0.3548
# Seed 328 - Test Accuracy: 0.4516
# Seed 329 - Test Accuracy: 0.3978
# Seed 330 - Test Accuracy: 0.3226
# Seed 331 - Test Accuracy: 0.5161
# Seed 332 - Test Accuracy: 0.3441
# Seed 333 - Test Accuracy: 0.4839
# Seed 334 - Test Accuracy: 0.4301
# Seed 335 - Test Accuracy: 0.5269
# Seed 336 - Test Accuracy: 0.3871
# Seed 337 - Test Accuracy: 0.5269
# Seed 338 - Test Accuracy: 0.4731
# Seed 339 - Test Accuracy: 0.4731
# Seed 340 - Test Accuracy: 0.4301
# Seed 341 - Test Accuracy: 0.3978
# Seed 342 - Test Accuracy: 0.4194
# Seed 343 - Test Accuracy: 0.4301
# Seed 344 - Test Accuracy: 0.4194
# Seed 345 - Test Accuracy: 0.3226
# Seed 346 - Test Accuracy: 0.3441
# Seed 347 - Test Accuracy: 0.4839
# Seed 348 - Test Accuracy: 0.4086
# Seed 349 - Test Accuracy: 0.4624
# Seed 350 - Test Accuracy: 0.3978
# Seed 351 - Test Accuracy: 0.4409
# Seed 352 - Test Accuracy: 0.4731
# Seed 353 - Test Accuracy: 0.4516
# Seed 354 - Test Accuracy: 0.4409
# Seed 355 - Test Accuracy: 0.4516
# Seed 356 - Test Accuracy: 0.4624
# Seed 357 - Test Accuracy: 0.4409
# Seed 358 - Test Accuracy: 0.3656
# Seed 359 - Test Accuracy: 0.4839
# Seed 360 - Test Accuracy: 0.4409
# Seed 361 - Test Accuracy: 0.3978
# Seed 362 - Test Accuracy: 0.4946
# Seed 363 - Test Accuracy: 0.3763
# Seed 364 - Test Accuracy: 0.2903
# Seed 365 - Test Accuracy: 0.4409
# Seed 366 - Test Accuracy: 0.4946
# Seed 367 - Test Accuracy: 0.3871
# Seed 368 - Test Accuracy: 0.4624
# Seed 369 - Test Accuracy: 0.4624
# Seed 370 - Test Accuracy: 0.4409
# Seed 371 - Test Accuracy: 0.4409
# Seed 372 - Test Accuracy: 0.4731
# Seed 373 - Test Accuracy: 0.4301
# Seed 374 - Test Accuracy: 0.5161
# Seed 375 - Test Accuracy: 0.3978
# Seed 376 - Test Accuracy: 0.4516
# Seed 377 - Test Accuracy: 0.3871
# Seed 378 - Test Accuracy: 0.3441
# Seed 379 - Test Accuracy: 0.4731
# Seed 380 - Test Accuracy: 0.3548
# Seed 381 - Test Accuracy: 0.4731
# Seed 382 - Test Accuracy: 0.3548
# Seed 383 - Test Accuracy: 0.4839
# Seed 384 - Test Accuracy: 0.4409
# Seed 385 - Test Accuracy: 0.3548
# Seed 386 - Test Accuracy: 0.4624
# Seed 387 - Test Accuracy: 0.4516
# Seed 388 - Test Accuracy: 0.4409
# Seed 389 - Test Accuracy: 0.4086
# Seed 390 - Test Accuracy: 0.4086
# Seed 391 - Test Accuracy: 0.3333
# Seed 392 - Test Accuracy: 0.4516
# Seed 393 - Test Accuracy: 0.4194
# Seed 394 - Test Accuracy: 0.4194
# Seed 395 - Test Accuracy: 0.4839
# Seed 396 - Test Accuracy: 0.4194
# Seed 397 - Test Accuracy: 0.4624
# Seed 398 - Test Accuracy: 0.4946
# Seed 399 - Test Accuracy: 0.4624
# Seed 400 - Test Accuracy: 0.3871
# Seed 401 - Test Accuracy: 0.4086
# Seed 402 - Test Accuracy: 0.5161
# Seed 403 - Test Accuracy: 0.4516
# Seed 404 - Test Accuracy: 0.3441
# Seed 405 - Test Accuracy: 0.3226
# Seed 406 - Test Accuracy: 0.4516
# Seed 407 - Test Accuracy: 0.4086
# Seed 408 - Test Accuracy: 0.4194
# Seed 409 - Test Accuracy: 0.4731
# Seed 410 - Test Accuracy: 0.4301
# Seed 411 - Test Accuracy: 0.4839
# Seed 412 - Test Accuracy: 0.4194
# Seed 413 - Test Accuracy: 0.4624
# Seed 414 - Test Accuracy: 0.4409
# Seed 415 - Test Accuracy: 0.4624
# Seed 416 - Test Accuracy: 0.4409
# Seed 417 - Test Accuracy: 0.4946
# Seed 418 - Test Accuracy: 0.3333
# Seed 419 - Test Accuracy: 0.4516
# Seed 420 - Test Accuracy: 0.4839
# Seed 421 - Test Accuracy: 0.4516
# Seed 422 - Test Accuracy: 0.4516
# Seed 423 - Test Accuracy: 0.4301
# Seed 424 - Test Accuracy: 0.4946
# Seed 425 - Test Accuracy: 0.3333
# Seed 426 - Test Accuracy: 0.3333
# Seed 427 - Test Accuracy: 0.4839
# Seed 428 - Test Accuracy: 0.4409
# Seed 429 - Test Accuracy: 0.4516
# Seed 430 - Test Accuracy: 0.4194
# Seed 431 - Test Accuracy: 0.5269
# Seed 432 - Test Accuracy: 0.4624
# Seed 433 - Test Accuracy: 0.4194
# Seed 434 - Test Accuracy: 0.4624
# Seed 435 - Test Accuracy: 0.3226
# Seed 436 - Test Accuracy: 0.4731
# Seed 437 - Test Accuracy: 0.3656
# Seed 438 - Test Accuracy: 0.4409
# Seed 439 - Test Accuracy: 0.4409
# Seed 440 - Test Accuracy: 0.3978
# Seed 441 - Test Accuracy: 0.3333
# Seed 442 - Test Accuracy: 0.4839
# Seed 443 - Test Accuracy: 0.4624
# Seed 444 - Test Accuracy: 0.3871
# Seed 445 - Test Accuracy: 0.4086
# Seed 446 - Test Accuracy: 0.3333
# Seed 447 - Test Accuracy: 0.3226
# Seed 448 - Test Accuracy: 0.4194
# Seed 449 - Test Accuracy: 0.5054
# Seed 450 - Test Accuracy: 0.3333
# Seed 451 - Test Accuracy: 0.3441
# Seed 452 - Test Accuracy: 0.4624
# Seed 453 - Test Accuracy: 0.3656
# Seed 454 - Test Accuracy: 0.3441
# Seed 455 - Test Accuracy: 0.3656
# Seed 456 - Test Accuracy: 0.4624
# Seed 457 - Test Accuracy: 0.4731
# Seed 458 - Test Accuracy: 0.4731
# Seed 459 - Test Accuracy: 0.4839
# Seed 460 - Test Accuracy: 0.4624
# Seed 461 - Test Accuracy: 0.4086
# Seed 462 - Test Accuracy: 0.3978
# Seed 463 - Test Accuracy: 0.3656
# Seed 464 - Test Accuracy: 0.4731
# Seed 465 - Test Accuracy: 0.4516
# Seed 466 - Test Accuracy: 0.4624
# Seed 467 - Test Accuracy: 0.3763
# Seed 468 - Test Accuracy: 0.3226
# Seed 469 - Test Accuracy: 0.4409
# Seed 470 - Test Accuracy: 0.5161
# Seed 471 - Test Accuracy: 0.4731
# Seed 472 - Test Accuracy: 0.4516
# Seed 473 - Test Accuracy: 0.4946
# Seed 474 - Test Accuracy: 0.4409
# Seed 475 - Test Accuracy: 0.4731
# Seed 476 - Test Accuracy: 0.3978
# Seed 477 - Test Accuracy: 0.4516
# Seed 478 - Test Accuracy: 0.4839
# Seed 479 - Test Accuracy: 0.3011
# Seed 480 - Test Accuracy: 0.4086
# Seed 481 - Test Accuracy: 0.4301
# Seed 482 - Test Accuracy: 0.4839
# Seed 483 - Test Accuracy: 0.4624
# Seed 484 - Test Accuracy: 0.4731
# Seed 485 - Test Accuracy: 0.4731
# Seed 486 - Test Accuracy: 0.4624
# Seed 487 - Test Accuracy: 0.3441
# Seed 488 - Test Accuracy: 0.4086
# Seed 489 - Test Accuracy: 0.4731
# Seed 490 - Test Accuracy: 0.4194
# Seed 491 - Test Accuracy: 0.4516
# Seed 492 - Test Accuracy: 0.4946
# Seed 493 - Test Accuracy: 0.3441
# Seed 494 - Test Accuracy: 0.4839
# Seed 495 - Test Accuracy: 0.4194
# Seed 496 - Test Accuracy: 0.3656
# Seed 497 - Test Accuracy: 0.4086
# Seed 498 - Test Accuracy: 0.5054
# Seed 499 - Test Accuracy: 0.4086
# Seed 500 - Test Accuracy: 0.5054
# Seed 501 - Test Accuracy: 0.4516
# Seed 502 - Test Accuracy: 0.4516
# Seed 503 - Test Accuracy: 0.3763
# Seed 504 - Test Accuracy: 0.4194
# Seed 505 - Test Accuracy: 0.5054
# Seed 506 - Test Accuracy: 0.4946
# Seed 507 - Test Accuracy: 0.3978
# Seed 508 - Test Accuracy: 0.4409
# Seed 509 - Test Accuracy: 0.4839
# Seed 510 - Test Accuracy: 0.4839
# Seed 511 - Test Accuracy: 0.4946
# Seed 512 - Test Accuracy: 0.4301
# Seed 513 - Test Accuracy: 0.5269
# Seed 514 - Test Accuracy: 0.4409
# Seed 515 - Test Accuracy: 0.4301
# Seed 516 - Test Accuracy: 0.3333
# Seed 517 - Test Accuracy: 0.3441
# Seed 518 - Test Accuracy: 0.4516
# Seed 519 - Test Accuracy: 0.3978
# Seed 520 - Test Accuracy: 0.3871
# Seed 521 - Test Accuracy: 0.3333
# Seed 522 - Test Accuracy: 0.4516
# Seed 523 - Test Accuracy: 0.3333
# Seed 524 - Test Accuracy: 0.4516
# Seed 525 - Test Accuracy: 0.4409
# Seed 526 - Test Accuracy: 0.4731
# Seed 527 - Test Accuracy: 0.4839
# Seed 528 - Test Accuracy: 0.3333
# Seed 529 - Test Accuracy: 0.3333
# Seed 530 - Test Accuracy: 0.4409
# Seed 531 - Test Accuracy: 0.3333
# Seed 532 - Test Accuracy: 0.4731
# Seed 533 - Test Accuracy: 0.4086
# Seed 534 - Test Accuracy: 0.4839
# Seed 535 - Test Accuracy: 0.4731
# Seed 536 - Test Accuracy: 0.4194
# Seed 537 - Test Accuracy: 0.4086
# Seed 538 - Test Accuracy: 0.4731
# Seed 539 - Test Accuracy: 0.4624
# Seed 540 - Test Accuracy: 0.4516
# Seed 541 - Test Accuracy: 0.4946
# Seed 542 - Test Accuracy: 0.4624
# Seed 543 - Test Accuracy: 0.4194
# Seed 544 - Test Accuracy: 0.4516
# Seed 545 - Test Accuracy: 0.4731
# Seed 546 - Test Accuracy: 0.4409
# Seed 547 - Test Accuracy: 0.4409
# Seed 548 - Test Accuracy: 0.4624
# Seed 549 - Test Accuracy: 0.4946
# Seed 550 - Test Accuracy: 0.4301
# Seed 551 - Test Accuracy: 0.4731
# Seed 552 - Test Accuracy: 0.4516
# Seed 553 - Test Accuracy: 0.4839
# Seed 554 - Test Accuracy: 0.4516
# Seed 555 - Test Accuracy: 0.4086
# Seed 556 - Test Accuracy: 0.4194
# Seed 557 - Test Accuracy: 0.3978
# Seed 558 - Test Accuracy: 0.4301
# Seed 559 - Test Accuracy: 0.4839
# Seed 560 - Test Accuracy: 0.4516
# Seed 561 - Test Accuracy: 0.4516
# Seed 562 - Test Accuracy: 0.4731
# Seed 563 - Test Accuracy: 0.4409
# Seed 564 - Test Accuracy: 0.5269
# Seed 565 - Test Accuracy: 0.3871
# Seed 566 - Test Accuracy: 0.4731
# Seed 567 - Test Accuracy: 0.4731
# Seed 568 - Test Accuracy: 0.3226
# Seed 569 - Test Accuracy: 0.3548
# Seed 570 - Test Accuracy: 0.4086
# Seed 571 - Test Accuracy: 0.3978
# Seed 572 - Test Accuracy: 0.4086
# Seed 573 - Test Accuracy: 0.3333
# Seed 574 - Test Accuracy: 0.4301
# Seed 575 - Test Accuracy: 0.3548
# Seed 576 - Test Accuracy: 0.4409
# Seed 577 - Test Accuracy: 0.4624
# Seed 578 - Test Accuracy: 0.4624
# Seed 579 - Test Accuracy: 0.4409
# Seed 580 - Test Accuracy: 0.4409
# Seed 581 - Test Accuracy: 0.5054
# Seed 582 - Test Accuracy: 0.4839
# Seed 583 - Test Accuracy: 0.4086
# Seed 584 - Test Accuracy: 0.4946
# Seed 585 - Test Accuracy: 0.3548
# Seed 586 - Test Accuracy: 0.4731
# Seed 587 - Test Accuracy: 0.4086
# Seed 588 - Test Accuracy: 0.4624
# Seed 589 - Test Accuracy: 0.4301
# Seed 590 - Test Accuracy: 0.3763
# Seed 591 - Test Accuracy: 0.3871
# Seed 592 - Test Accuracy: 0.3333
# Seed 593 - Test Accuracy: 0.4301
# Seed 594 - Test Accuracy: 0.4194
# Seed 595 - Test Accuracy: 0.4409
# Seed 596 - Test Accuracy: 0.3871
# Seed 597 - Test Accuracy: 0.4409
# Seed 598 - Test Accuracy: 0.4839
# Seed 599 - Test Accuracy: 0.4731
# Seed 600 - Test Accuracy: 0.4194
# Seed 601 - Test Accuracy: 0.4194
# Seed 602 - Test Accuracy: 0.4839
# Seed 603 - Test Accuracy: 0.5484
# Seed 604 - Test Accuracy: 0.3871
# Seed 605 - Test Accuracy: 0.4624
# Seed 606 - Test Accuracy: 0.5054
# Seed 607 - Test Accuracy: 0.5161
# Seed 608 - Test Accuracy: 0.5054
# Seed 609 - Test Accuracy: 0.4194
# Seed 610 - Test Accuracy: 0.3441
# Seed 611 - Test Accuracy: 0.4516
# Seed 612 - Test Accuracy: 0.4086
# Seed 613 - Test Accuracy: 0.4731
# Seed 614 - Test Accuracy: 0.4086
# Seed 615 - Test Accuracy: 0.4301
# Seed 616 - Test Accuracy: 0.4516
# Seed 617 - Test Accuracy: 0.4624
# Seed 618 - Test Accuracy: 0.3978
# Seed 619 - Test Accuracy: 0.5054
# Seed 620 - Test Accuracy: 0.4301
# Seed 621 - Test Accuracy: 0.4731
# Seed 622 - Test Accuracy: 0.3441
# Seed 623 - Test Accuracy: 0.3978
# Seed 624 - Test Accuracy: 0.3978
# Seed 625 - Test Accuracy: 0.4516
# Seed 626 - Test Accuracy: 0.4839
# Seed 627 - Test Accuracy: 0.4301
# Seed 628 - Test Accuracy: 0.4624
# Seed 629 - Test Accuracy: 0.4946
# Seed 630 - Test Accuracy: 0.4516
# Seed 631 - Test Accuracy: 0.3656
# Seed 632 - Test Accuracy: 0.4731
# Seed 633 - Test Accuracy: 0.4946
# Seed 634 - Test Accuracy: 0.4516
# Seed 635 - Test Accuracy: 0.4946
# Seed 636 - Test Accuracy: 0.5269
# Seed 637 - Test Accuracy: 0.4194
# Seed 638 - Test Accuracy: 0.3978
# Seed 639 - Test Accuracy: 0.4301
# Seed 640 - Test Accuracy: 0.4301
# Seed 641 - Test Accuracy: 0.4731
# Seed 642 - Test Accuracy: 0.4731
# Seed 643 - Test Accuracy: 0.3871
# Seed 644 - Test Accuracy: 0.4731
# Seed 645 - Test Accuracy: 0.4086
# Seed 646 - Test Accuracy: 0.3548
# Seed 647 - Test Accuracy: 0.4731
# Seed 648 - Test Accuracy: 0.5054
# Seed 649 - Test Accuracy: 0.4946
# Seed 650 - Test Accuracy: 0.4301
# Seed 651 - Test Accuracy: 0.3226
# Seed 652 - Test Accuracy: 0.3333
# Seed 653 - Test Accuracy: 0.4194
# Seed 654 - Test Accuracy: 0.4409
# Seed 655 - Test Accuracy: 0.3978
# Seed 656 - Test Accuracy: 0.4624
# Seed 657 - Test Accuracy: 0.3548
# Seed 658 - Test Accuracy: 0.3978
# Seed 659 - Test Accuracy: 0.4086
# Seed 660 - Test Accuracy: 0.5591
# Seed 661 - Test Accuracy: 0.5161
# Seed 662 - Test Accuracy: 0.4194
# Seed 663 - Test Accuracy: 0.3656
# Seed 664 - Test Accuracy: 0.4946
# Seed 665 - Test Accuracy: 0.4516
# Seed 666 - Test Accuracy: 0.3333
# Seed 667 - Test Accuracy: 0.3656
# Seed 668 - Test Accuracy: 0.4409
# Seed 669 - Test Accuracy: 0.4624
# Seed 670 - Test Accuracy: 0.4301
# Seed 671 - Test Accuracy: 0.3978
# Seed 672 - Test Accuracy: 0.3871
# Seed 673 - Test Accuracy: 0.2258
# Seed 674 - Test Accuracy: 0.4946
# Seed 675 - Test Accuracy: 0.4946
# Seed 676 - Test Accuracy: 0.4409
# Seed 677 - Test Accuracy: 0.4194
# Seed 678 - Test Accuracy: 0.4301
# Seed 679 - Test Accuracy: 0.4624
# Seed 680 - Test Accuracy: 0.4301
# Seed 681 - Test Accuracy: 0.3656
# Seed 682 - Test Accuracy: 0.4301
# Seed 683 - Test Accuracy: 0.3871
# Seed 684 - Test Accuracy: 0.3978
# Seed 685 - Test Accuracy: 0.4624
# Seed 686 - Test Accuracy: 0.4409
# Seed 687 - Test Accuracy: 0.4301
# Seed 688 - Test Accuracy: 0.4301
# Seed 689 - Test Accuracy: 0.4731
# Seed 690 - Test Accuracy: 0.4624
# Seed 691 - Test Accuracy: 0.4946
# Seed 692 - Test Accuracy: 0.4946
# Seed 693 - Test Accuracy: 0.4516
# Seed 694 - Test Accuracy: 0.4839
# Seed 695 - Test Accuracy: 0.3763
# Seed 696 - Test Accuracy: 0.5054
# Seed 697 - Test Accuracy: 0.4516
# Seed 698 - Test Accuracy: 0.4194
# Seed 699 - Test Accuracy: 0.4516
# Seed 700 - Test Accuracy: 0.4301
# Seed 701 - Test Accuracy: 0.4516
# Seed 702 - Test Accuracy: 0.4194
# Seed 703 - Test Accuracy: 0.4839
# Seed 704 - Test Accuracy: 0.4516
# Seed 705 - Test Accuracy: 0.4839
# Seed 706 - Test Accuracy: 0.3548
# Seed 707 - Test Accuracy: 0.4516
# Seed 708 - Test Accuracy: 0.4731
# Seed 709 - Test Accuracy: 0.4086
# Seed 710 - Test Accuracy: 0.5054
# Seed 711 - Test Accuracy: 0.3871
# Seed 712 - Test Accuracy: 0.4194
# Seed 713 - Test Accuracy: 0.3656
# Seed 714 - Test Accuracy: 0.4839
# Seed 715 - Test Accuracy: 0.4839
# Seed 716 - Test Accuracy: 0.3548
# Seed 717 - Test Accuracy: 0.4086
# Seed 718 - Test Accuracy: 0.4194
# Seed 719 - Test Accuracy: 0.3333
# Seed 720 - Test Accuracy: 0.4301
# Seed 721 - Test Accuracy: 0.5269
# Seed 722 - Test Accuracy: 0.4731
# Seed 723 - Test Accuracy: 0.4301
# Seed 724 - Test Accuracy: 0.4516
# Seed 725 - Test Accuracy: 0.4409
# Seed 726 - Test Accuracy: 0.3333
# Seed 727 - Test Accuracy: 0.4624
# Seed 728 - Test Accuracy: 0.4301
# Seed 729 - Test Accuracy: 0.3441
# Seed 730 - Test Accuracy: 0.4194
# Seed 731 - Test Accuracy: 0.3548
# Seed 732 - Test Accuracy: 0.4409
# Seed 733 - Test Accuracy: 0.4731
# Seed 734 - Test Accuracy: 0.3011
# Seed 735 - Test Accuracy: 0.4194
# Seed 736 - Test Accuracy: 0.4624
# Seed 737 - Test Accuracy: 0.4409
# Seed 738 - Test Accuracy: 0.4731
# Seed 739 - Test Accuracy: 0.3763
# Seed 740 - Test Accuracy: 0.5269
# Seed 741 - Test Accuracy: 0.3656
# Seed 742 - Test Accuracy: 0.4409
# Seed 743 - Test Accuracy: 0.4516
# Seed 744 - Test Accuracy: 0.4839
# Seed 745 - Test Accuracy: 0.4731
# Seed 746 - Test Accuracy: 0.4946
# Seed 747 - Test Accuracy: 0.4516
# Seed 748 - Test Accuracy: 0.3548
# Seed 749 - Test Accuracy: 0.4624
# Seed 750 - Test Accuracy: 0.3978
# Seed 751 - Test Accuracy: 0.3763
# Seed 752 - Test Accuracy: 0.4301
# Seed 753 - Test Accuracy: 0.4086
# Seed 754 - Test Accuracy: 0.4301
# Seed 755 - Test Accuracy: 0.4946
# Seed 756 - Test Accuracy: 0.4839
# Seed 757 - Test Accuracy: 0.4624
# Seed 758 - Test Accuracy: 0.4516
# Seed 759 - Test Accuracy: 0.3548
# Seed 760 - Test Accuracy: 0.3441
# Seed 761 - Test Accuracy: 0.4516
# Seed 762 - Test Accuracy: 0.4946
# Seed 763 - Test Accuracy: 0.3548
# Seed 764 - Test Accuracy: 0.4086
# Seed 765 - Test Accuracy: 0.5054
# Seed 766 - Test Accuracy: 0.4409
# Seed 767 - Test Accuracy: 0.4086
# Seed 768 - Test Accuracy: 0.3763
# Seed 769 - Test Accuracy: 0.4086
# Seed 770 - Test Accuracy: 0.4516
# Seed 771 - Test Accuracy: 0.4301
# Seed 772 - Test Accuracy: 0.4624
# Seed 773 - Test Accuracy: 0.4301
# Seed 774 - Test Accuracy: 0.4409
# Seed 775 - Test Accuracy: 0.3656
# Seed 776 - Test Accuracy: 0.3548
# Seed 777 - Test Accuracy: 0.4839
# Seed 778 - Test Accuracy: 0.4516
# Seed 779 - Test Accuracy: 0.4086
# Seed 780 - Test Accuracy: 0.3441
# Seed 781 - Test Accuracy: 0.3871
# Seed 782 - Test Accuracy: 0.4624
# Seed 783 - Test Accuracy: 0.4516
# Seed 784 - Test Accuracy: 0.4624
# Seed 785 - Test Accuracy: 0.5054
# Seed 786 - Test Accuracy: 0.4086
# Seed 787 - Test Accuracy: 0.4731
# Seed 788 - Test Accuracy: 0.4194
# Seed 789 - Test Accuracy: 0.4409
# Seed 790 - Test Accuracy: 0.4839
# Seed 791 - Test Accuracy: 0.4409
# Seed 792 - Test Accuracy: 0.3548
# Seed 793 - Test Accuracy: 0.3978
# Seed 794 - Test Accuracy: 0.5054
# Seed 795 - Test Accuracy: 0.4624
# Seed 796 - Test Accuracy: 0.4731
# Seed 797 - Test Accuracy: 0.4731
# Seed 798 - Test Accuracy: 0.3011
# Seed 799 - Test Accuracy: 0.4194
# Seed 800 - Test Accuracy: 0.3871
# Seed 801 - Test Accuracy: 0.3978
# Seed 802 - Test Accuracy: 0.3333
# Seed 803 - Test Accuracy: 0.4301
# Seed 804 - Test Accuracy: 0.5161
# Seed 805 - Test Accuracy: 0.4409
# Seed 806 - Test Accuracy: 0.3333
# Seed 807 - Test Accuracy: 0.4409
# Seed 808 - Test Accuracy: 0.4516
# Seed 809 - Test Accuracy: 0.4731
# Seed 810 - Test Accuracy: 0.3548
# Seed 811 - Test Accuracy: 0.4301
# Seed 812 - Test Accuracy: 0.4624
# Seed 813 - Test Accuracy: 0.4194
# Seed 814 - Test Accuracy: 0.4516
# Seed 815 - Test Accuracy: 0.4731
# Seed 816 - Test Accuracy: 0.4301
# Seed 817 - Test Accuracy: 0.4086
# Seed 818 - Test Accuracy: 0.3548
# Seed 819 - Test Accuracy: 0.3226
# Seed 820 - Test Accuracy: 0.3763
# Seed 821 - Test Accuracy: 0.4624
# Seed 822 - Test Accuracy: 0.3441
# Seed 823 - Test Accuracy: 0.4946
# Seed 824 - Test Accuracy: 0.4624
# Seed 825 - Test Accuracy: 0.4301
# Seed 826 - Test Accuracy: 0.3871
# Seed 827 - Test Accuracy: 0.4086
# Seed 828 - Test Accuracy: 0.4301
# Seed 829 - Test Accuracy: 0.4731
# Seed 830 - Test Accuracy: 0.4086
# Seed 831 - Test Accuracy: 0.4731
# Seed 832 - Test Accuracy: 0.3118
# Seed 833 - Test Accuracy: 0.4194
# Seed 834 - Test Accuracy: 0.4516
# Seed 835 - Test Accuracy: 0.4516
# Seed 836 - Test Accuracy: 0.4731
# Seed 837 - Test Accuracy: 0.4946
# Seed 838 - Test Accuracy: 0.4301
# Seed 839 - Test Accuracy: 0.4624
# Seed 840 - Test Accuracy: 0.3763
# Seed 841 - Test Accuracy: 0.4624
# Seed 842 - Test Accuracy: 0.4409
# Seed 843 - Test Accuracy: 0.4624
# Seed 844 - Test Accuracy: 0.3763
# Seed 845 - Test Accuracy: 0.4516
# Seed 846 - Test Accuracy: 0.4409
# Seed 847 - Test Accuracy: 0.3333
# Seed 848 - Test Accuracy: 0.4516
# Seed 849 - Test Accuracy: 0.4301
# Seed 850 - Test Accuracy: 0.4194
# Seed 851 - Test Accuracy: 0.4301
# Seed 852 - Test Accuracy: 0.4731
# Seed 853 - Test Accuracy: 0.3226
# Seed 854 - Test Accuracy: 0.4731
# Seed 855 - Test Accuracy: 0.4516
# Seed 856 - Test Accuracy: 0.4624
# Seed 857 - Test Accuracy: 0.3978
# Seed 858 - Test Accuracy: 0.4946
# Seed 859 - Test Accuracy: 0.3656
# Seed 860 - Test Accuracy: 0.4086
# Seed 861 - Test Accuracy: 0.4409
# Seed 862 - Test Accuracy: 0.4194
# Seed 863 - Test Accuracy: 0.5269
# Seed 864 - Test Accuracy: 0.5484
# Seed 865 - Test Accuracy: 0.3871
# Seed 866 - Test Accuracy: 0.4624
# Seed 867 - Test Accuracy: 0.4301
# Seed 868 - Test Accuracy: 0.4516
# Seed 869 - Test Accuracy: 0.4516
# Seed 870 - Test Accuracy: 0.3871
# Seed 871 - Test Accuracy: 0.4194
# Seed 872 - Test Accuracy: 0.4731
# Seed 873 - Test Accuracy: 0.3656
# Seed 874 - Test Accuracy: 0.4301
# Seed 875 - Test Accuracy: 0.4731
# Seed 876 - Test Accuracy: 0.4839
# Seed 877 - Test Accuracy: 0.4301
# Seed 878 - Test Accuracy: 0.4839
# Seed 879 - Test Accuracy: 0.4731
# Seed 880 - Test Accuracy: 0.4839
# Seed 881 - Test Accuracy: 0.3333
# Seed 882 - Test Accuracy: 0.4194
# Seed 883 - Test Accuracy: 0.3441
# Seed 884 - Test Accuracy: 0.4409
# Seed 885 - Test Accuracy: 0.4409
# Seed 886 - Test Accuracy: 0.4839
# Seed 887 - Test Accuracy: 0.4624
# Seed 888 - Test Accuracy: 0.2796
# Seed 889 - Test Accuracy: 0.3656
# Seed 890 - Test Accuracy: 0.4086
# Seed 891 - Test Accuracy: 0.4194
# Seed 892 - Test Accuracy: 0.4731
# Seed 893 - Test Accuracy: 0.5161
# Seed 894 - Test Accuracy: 0.4731
# Seed 895 - Test Accuracy: 0.4086
# Seed 896 - Test Accuracy: 0.4086
# Seed 897 - Test Accuracy: 0.4624
# Seed 898 - Test Accuracy: 0.3548
# Seed 899 - Test Accuracy: 0.4301
# Seed 900 - Test Accuracy: 0.3441
# Seed 901 - Test Accuracy: 0.4301
# Seed 902 - Test Accuracy: 0.4301
# Seed 903 - Test Accuracy: 0.5054
# Seed 904 - Test Accuracy: 0.3763
# Seed 905 - Test Accuracy: 0.4839
# Seed 906 - Test Accuracy: 0.4839
# Seed 907 - Test Accuracy: 0.3441
# Seed 908 - Test Accuracy: 0.4731
# Seed 909 - Test Accuracy: 0.4731
# Seed 910 - Test Accuracy: 0.3978
# Seed 911 - Test Accuracy: 0.3441
# Seed 912 - Test Accuracy: 0.4409
# Seed 913 - Test Accuracy: 0.4194
# Seed 914 - Test Accuracy: 0.4301
# Seed 915 - Test Accuracy: 0.5054
# Seed 916 - Test Accuracy: 0.3871
# Seed 917 - Test Accuracy: 0.5161
# Seed 918 - Test Accuracy: 0.4086
# Seed 919 - Test Accuracy: 0.3548
# Seed 920 - Test Accuracy: 0.4409
# Seed 921 - Test Accuracy: 0.4409
# Seed 922 - Test Accuracy: 0.4624
# Seed 923 - Test Accuracy: 0.3656
# Seed 924 - Test Accuracy: 0.4839
# Seed 925 - Test Accuracy: 0.3871
# Seed 926 - Test Accuracy: 0.4516
# Seed 927 - Test Accuracy: 0.3441
# Seed 928 - Test Accuracy: 0.3333
# Seed 929 - Test Accuracy: 0.3118
# Seed 930 - Test Accuracy: 0.3656
# Seed 931 - Test Accuracy: 0.4409
# Seed 932 - Test Accuracy: 0.3978
# Seed 933 - Test Accuracy: 0.4409
# Seed 934 - Test Accuracy: 0.4086
# Seed 935 - Test Accuracy: 0.4946
# Seed 936 - Test Accuracy: 0.4731
# Seed 937 - Test Accuracy: 0.4086
# Seed 938 - Test Accuracy: 0.4301
# Seed 939 - Test Accuracy: 0.2473
# Seed 940 - Test Accuracy: 0.4839
# Seed 941 - Test Accuracy: 0.4839
# Seed 942 - Test Accuracy: 0.4194
# Seed 943 - Test Accuracy: 0.4409
# Seed 944 - Test Accuracy: 0.3548
# Seed 945 - Test Accuracy: 0.3656
# Seed 946 - Test Accuracy: 0.4301
# Seed 947 - Test Accuracy: 0.4731
# Seed 948 - Test Accuracy: 0.4731
# Seed 949 - Test Accuracy: 0.4086
# Seed 950 - Test Accuracy: 0.5269
# Seed 951 - Test Accuracy: 0.4409
# Seed 952 - Test Accuracy: 0.4409
# Seed 953 - Test Accuracy: 0.4946
# Seed 954 - Test Accuracy: 0.5484
# Seed 955 - Test Accuracy: 0.4946
# Seed 956 - Test Accuracy: 0.4409
# Seed 957 - Test Accuracy: 0.3333
# Seed 958 - Test Accuracy: 0.4409
# Seed 959 - Test Accuracy: 0.4624
# Seed 960 - Test Accuracy: 0.3226
# Seed 961 - Test Accuracy: 0.3118
# Seed 962 - Test Accuracy: 0.4624
# Seed 963 - Test Accuracy: 0.4086
# Seed 964 - Test Accuracy: 0.3978
# Seed 965 - Test Accuracy: 0.4731
# Seed 966 - Test Accuracy: 0.3763
# Seed 967 - Test Accuracy: 0.4516
# Seed 968 - Test Accuracy: 0.3441
# Seed 969 - Test Accuracy: 0.4839
# Seed 970 - Test Accuracy: 0.4409
# Seed 971 - Test Accuracy: 0.5269
# Seed 972 - Test Accuracy: 0.4624
# Seed 973 - Test Accuracy: 0.4839
# Seed 974 - Test Accuracy: 0.4301
# Seed 975 - Test Accuracy: 0.4839
# Seed 976 - Test Accuracy: 0.4516
# Seed 977 - Test Accuracy: 0.3226
# Seed 978 - Test Accuracy: 0.4516
# Seed 979 - Test Accuracy: 0.3871
# Seed 980 - Test Accuracy: 0.4301
# Seed 981 - Test Accuracy: 0.4624
# Seed 982 - Test Accuracy: 0.4516
# Seed 983 - Test Accuracy: 0.5054
# Seed 984 - Test Accuracy: 0.4194
# Seed 985 - Test Accuracy: 0.3441
# Seed 986 - Test Accuracy: 0.4086
# Seed 987 - Test Accuracy: 0.4516
# Seed 988 - Test Accuracy: 0.4839
# Seed 989 - Test Accuracy: 0.3548
# Seed 990 - Test Accuracy: 0.4086
# Seed 991 - Test Accuracy: 0.3118
# Seed 992 - Test Accuracy: 0.4194
# Seed 993 - Test Accuracy: 0.3656
# Seed 994 - Test Accuracy: 0.4624
# Seed 995 - Test Accuracy: 0.3871
# Seed 996 - Test Accuracy: 0.4839
# Seed 997 - Test Accuracy: 0.3763
# Seed 998 - Test Accuracy: 0.4086
# Seed 999 - Test Accuracy: 0.5161
#
# Seed terbaik: 660
# Akurasi tertinggi: 55.91%

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from tensorflow.keras.models import load_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.regularizers import l2

# Load the saved model with custom objects and compile it
model_path = './model_slide_window/IndRNNAug5400_Slide_revisi.h5'
custom_objects = {'IndRNN': IndRNN}  # Sesuaikan jika ada objek khusus lainnya
kfold = KFold(n_splits=5, shuffle=True, random_state=42)

# Prepare lists to store scores and histories
scores = []
histories = []

# Manual cross-validation with history tracking
for fold, (train_index, test_index) in enumerate(kfold.split(x_test, y_test), 1):
    # Load and compile model for each fold
    model = load_model(model_path, custom_objects=custom_objects, compile=False)
    model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])
    
    # Split data into training and validation sets for this fold
    x_train_fold, x_val_fold = x_test[train_index], x_test[test_index]
    y_train_fold, y_val_fold = y_test[train_index], y_test[test_index]

    # Train the model and record the history
    history = model.fit(
        x_train_fold, y_train_fold, 
        validation_data=(x_val_fold, y_val_fold), 
        epochs=10, batch_size=8, verbose=0  # Sesuaikan epoch dan batch size jika diperlukan
    )
    
    # Save accuracy score and history
    score = model.evaluate(x_val_fold, y_val_fold, verbose=0)
    scores.append(score[1])  # Akurasi dari evaluasi
    histories.append(history.history)  # Menyimpan seluruh data history

    # Visualize accuracy per epoch for this fold
    plt.plot(history.history['accuracy'], label=f'Fold {fold} - Training Accuracy')
    plt.plot(history.history['val_accuracy'], label=f'Fold {fold} - Validation Accuracy')

# Final plot customization
plt.title("Training and Validation Accuracy per Fold")
plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Print average accuracy across all folds
print("Akurasi untuk setiap fold:", scores)
print("Rata-rata akurasi:", np.mean(scores))
# Out:
# Akurasi untuk setiap fold: [0.31578946113586426, 0.31578946113586426, 0.31578946113586426, 0.5, 0.3888888955116272]
# Rata-rata akurasi: 0.367251455783844

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from ind_rnn import IndRNN  # Pastikan library IndRNN tersedia atau implementasikan sesuai kebutuhan

# Constants
WINDOW_LEN = 5400
N_FEATURE = 2

# Define the paths in a dictionary (for train, val, and test)
data_paths = {
    'train': [
        'F:/Tugas Akhir/Split_revisi_3-1/train/shuffled_1_train.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/train/shuffled_2_train.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/train/shuffled_3_train.npy',
    ],
    'val': [
        'F:/Tugas Akhir/Split_revisi_3-1/val/shuffled_1_val.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/val/shuffled_2_val.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/val/shuffled_3_val.npy',
    ],
    'test': [
        'F:/Tugas Akhir/Split_revisi_3-1/test/shuffled_1_test.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/test/shuffled_2_test.npy',
        'F:/Tugas Akhir/Split_revisi_3-1/test/shuffled_3_test.npy',
    ]
}

# Function to load, process, modify labels, and apply one-hot encoding
def load_and_process_data(data_paths):
    processed_data = {}
    
    for split in ['train', 'val', 'test']:
        x_data = []
        y_data = []
        
        # Load and concatenate data
        for path in data_paths[split]:
            data = np.load(path, allow_pickle=True)  # allow_pickle=True to load object arrays if needed
            # Mengakses fitur 'ear_x', 'mar_x', dan 'label'
            ear_x = data[:, :, 0]  # Semua window, semua elemen dalam window, kolom 0 (ear_x)
            mar_x = data[:, :, 1]  # Semua window, semua elemen dalam window, kolom 1 (mar_x)
            label = data[:, 0, 2]  # Semua window, label diambil dari elemen pertama
            
            # Combine 'ear_x' and 'mar_x' as features (combine along axis 1)
            features = np.stack((ear_x, mar_x), axis=-1)  # Shape: (samples, WINDOW_LEN, N_FEATURE)
            
            x_data.append(features)
            y_data.append(label)
        
        # Concatenate along the first axis (samples)
        x_data = np.vstack(x_data)
        y_data = np.concatenate(y_data)
        
        # One-hot encode the labels (0 -> [1, 0], 1 -> [0, 1])
        y_data = pd.get_dummies(y_data).values  # Shape: (num_samples, 2)
        
        # Store the processed data
        processed_data[split] = (x_data, y_data)
        
    return processed_data

# Load and process the data
processed_data = load_and_process_data(data_paths)

# Access the processed data
x_train, y_train = processed_data['train']
x_val, y_val = processed_data['val']
x_test, y_test = processed_data['test']

print(f"x_train original shape: {x_train.shape}")


# Reshape the data to (samples, WINDOW_LEN, N_FEATURE)
x_train = x_train.reshape(-1, WINDOW_LEN, N_FEATURE)
x_val = x_val.reshape(-1, WINDOW_LEN, N_FEATURE)
x_test = x_test.reshape(-1, WINDOW_LEN, N_FEATURE)

# Check the shapes and label values
print(f"Train data shape: {x_train.shape}, Train labels shape: {y_train.shape}")
print(f"Validation data shape: {x_val.shape}, Validation labels shape: {y_val.shape}")
print(f"Test data shape: {x_test.shape}, Test labels shape: {y_test.shape}")

# Display unique labels in each dataset (after one-hot encoding)
print(f"Unique labels in train set: {np.unique(np.argmax(y_train, axis=1))}")
print(f"Unique labels in validation set: {np.unique(np.argmax(y_val, axis=1))}")
print(f"Unique labels in test set: {np.unique(np.argmax(y_test, axis=1))}")

label_counts = np.sum(y_train, axis=0)
print(f"Jumlah label kelas 0: {label_counts[0]}, Jumlah label kelas 1: {label_counts[1]}")

# Set random seed for reproducibility
np.random.seed(7)
random.seed(7)
tf.random.set_seed(7)

# 1. Load the trained model
model = load_model('F:/Tugas Akhir/Itqan/model_slide_window/IndRNNAug5400_Slide_revisi.h5', custom_objects={'IndRNN': IndRNN}, compile=False)  # Pastikan model sudah dilatih dan disimpan

# 2. Make predictions on the test set
y_pred_prob = model.predict(x_test)  # Prediksi probabilitas
y_pred = np.argmax(y_pred_prob, axis=1)  # Get class with highest probability

# 3. Convert one-hot encoded labels to class labels (if necessary)
y_test_labels = np.argmax(y_test, axis=1)

# 4. Generate the confusion matrix
cm = confusion_matrix(y_test_labels, y_pred)

# 5. Visualize the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[str(i) for i in range(y_test.shape[1])])  # Use the number of classes in y_test
disp.plot(cmap='Blues')
plt.title("Confusion Matrix")
plt.show()
# Out:
# x_train original shape: (213, 5400, 2)
# Train data shape: (213, 5400, 2), Train labels shape: (213, 3)
# Validation data shape: (72, 5400, 2), Validation labels shape: (72, 3)
# Test data shape: (93, 5400, 2), Test labels shape: (93, 3)
# Unique labels in train set: [0 1 2]
# Unique labels in validation set: [0 1 2]
# Unique labels in test set: [0 1 2]
# Jumlah label kelas 0: 71, Jumlah label kelas 1: 71
# 3/3 [==============================] - 1s 175ms/step
